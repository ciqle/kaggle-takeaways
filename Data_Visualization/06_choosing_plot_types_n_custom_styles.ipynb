# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# In this course, you've learned how to create many different chart types. Now, you'll organize your knowledge, before learning some quick commands that you can use to change the style of your charts.

# %% [markdown]
# ## What have you learned?
# ![image](https://storage.googleapis.com/kaggle-media/learn/images/LPWH19I.png)

# %% [markdown]
# * **Trends** - A trend is defined as a pattern of change.
#   * `[sns.lineplot]` - **Line charts** are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# * **Relationship** - There are many different chart types that you can use to understand relationships between variables in your data.
#   * `[sns.barplot]` - **Bar charts** are useful for comparing quantities corresponding to different groups.
#   * `[sns.heatmap]` - **Heatmaps** can be used to find color-coded patterns in tables of numbers.
#   * `[sns.scatterplot]` - **Scatter plots** show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third categorical variable.
#   * `[sns.regplot]` - Including a **regression line** in the scatter plot makes it easier to see any linear relationship between two variables.
#   * `[sns.lmplot]` - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#   * `[sns.swarmplot]` - **Categorical scatter plots** show the relationship between a continuous variable and a categorical variable.
#
# * **Distribution** - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#   * `[sns.histplot]` - **Histograms** show the distribution of a single numerical variable.
#   * `[sns.kdeplot]` - **KDE plots** (or **2D KDE plots**) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#   * `[sns.jointplot]` - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.

# %% [markdown]
# * **趋势** - 趋势是指变化的模式。
#   * `[sns.lineplot]` - **折线图**最适合展示随时间变化的趋势，多条折线可呈现不同组别的趋势对比。
#
# * **关系** - 多种图表类型可用于理解变量间的关系。
#   * `[sns.barplot]` - **条形图**用于比较不同组别的数量差异。
#   * `[sns.heatmap]` - **热力图**可通过颜色编码识别表格中的数值模式。
#   * `[sns.scatterplot]` - **散点图**展示两个连续变量间的关系；若使用颜色编码，还可关联第三个分类变量。
#   * `[sns.regplot]` - 在散点图中添加**回归线**能更直观显示两个变量间的线性关系。
#   * `[sns.lmplot]` - 若散点图包含多个颜色编码的组别，此命令可为每组绘制独立的回归线。
#   * `[sns.swarmplot]` - **分类散点图**展示连续变量与分类变量间的关系。
#
# * **分布** - 分布图用于展示变量的可能取值及其出现概率。
#   * `[sns.histplot]` - **直方图**显示单个数值变量的分布。
#   * `[sns.kdeplot]` - **核密度估计图**（或**二维核密度估计图**）以平滑曲线形式估计单变量（或双变量）的分布。
#   * `[sns.jointplot]` - 此命令可同时展示双变量的二维核密度估计图及各自单变量的核密度估计图。

# %% [markdown]
# ## Changing styles with seaborn
#
# All of the commands have provided a nice, default style to each of the plots. However, you may find it useful to customize how your plots look, and thankfully, this can be accomplished by just adding one more line of code!
#
# 所有命令都为每个绘图提供了漂亮的默认样式。不过，您可能会发现自定义绘图的外观非常有用，幸好只需添加一行代码就能实现！

# %% [markdown]
# We'll work with the same code that we used to create a line chart in a previous tutorial. The code below loads the dataset and creates the chart.
#
# 我们将使用与上一教程中创建折线图相同的代码。下面的代码会加载数据集并创建图表。

# %%
# Path of the file to read
spotify_filepath = "./input/spotify.csv"

# Read the file into a variable spotify_data
spotify_data = pd.read_csv(spotify_filepath, index_col="Date", parse_dates=True)

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %%
spotify_data.head()
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN

# %% [markdown]
# We can quickly change the style of the figure to a different theme with only a single line of code.
#
# 只需一行代码，我们就能快速将图的样式更改为不同的主题。

# %%
# Change the style of the figure to the "dark" theme
sns.set_style("dark")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# Seaborn has five different themes: (1)`"darkgrid"`, (2)`"whitegrid"`, (3)`"dark"`, (4)`"white"`, and (5)`"ticks"`, and you need only use a command similar to the one in the code cell above (with the chosen theme filled in) to change it.
#
# In the upcoming exercise, you'll experiment with these themes to see which one you like most!
#
# Seaborn 有五种不同的主题：(1)`"darkgrid"`, (2)`"whitegrid"`, (3)`"dark"`, (4)`"white"`, and (5)`"ticks"`。
#
# 在接下来的练习中，你将尝试使用这些主题，看看自己最喜欢哪一个！

# %%
# Change the style of the figure to the "darkgrid" theme
sns.set_style("darkgrid")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %%
# Change the style of the figure to the "whitegrid" theme
sns.set_style("whitegrid")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %%
# Change the style of the figure to the "ticks" theme
sns.set_style("ticks")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>

# %%
# Change the style of the figure to the "white" theme
sns.set_style("white")

# Line chart 
plt.figure(figsize=(12,6))
sns.lineplot(data=spotify_data)
# Out:
# <Axes: xlabel='Date'>
